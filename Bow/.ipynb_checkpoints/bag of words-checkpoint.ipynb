# %%
import pandas as pd
import numpy as np

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
X_text = []
Y = [ ]
with open('source_task_train.csv','r') as f:
    print(f.readline())
    for line in f:
        data = line.split(',')
        X_text.append(data[1])
        Y.append(data[2])
# Out:
# _id,text,label

# %%
Y = np.array(Y)

# %%
X_text[:2]
# Out:
# ['Простенькая можно сказать убогая книга..... для плохо развитых мало читающих людей. Дешёвая бумага простенькие иллюстрации. Жаль денег жаль! Даже детям нельзя подарить такую дрянь.....   ',
#  'Пиво — это конечно полный провал. Мне кажется что такой бывший сильным бренд Coffee Project выбирает неправильный путь развития. Но конечно это ваш выбор. Успехов. P.S. Отступать от своих принципов — последнее дело.']

# %%
count_vectorizer = CountVectorizer(max_df=0.9, min_df=2)

# %%
count_vectorizer.fit(X_text)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.9, max_features=None, min_df=2,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
X = count_vectorizer.transform(X_text)

# %%
from sklearn.decomposition import PCA, TruncatedSVD, IncrementalPCA

# %%
X.shape
# Out:
# (154371, 160880)

# %%
_pca = TruncatedSVD(n_components=2)

# %%
X_pca =  _pca.fit_transform(X)

# %%
X
# Out:
# <154371x160880 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7142012 stored elements in Compressed Sparse Row format>

# %%
from scipy.sparse import csr_matrix, hstack, vstack

# %%
# csr_matrix(X_pca)

# %%
# hstack([X, X_pca])

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
lg = LogisticRegression(
    penalty='l2',
    C=10, 
    n_jobs=-1, verbose=1, 
    
    solver='sag', multi_class='multinomial',
    
    max_iter=300
)
lg.fit(X_train, Y_train)
# Out:
# max_iter reached after 89 seconds
# /Users/talipov/MyProjects/projectX/acosta_env/lib/python3.6/site-packages/sklearn/linear_model/sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  1.5min finished
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=300, multi_class='multinomial',
#           n_jobs=-1, penalty='l2', random_state=None, solver='sag',
#           tol=0.0001, verbose=1, warm_start=False)

# %%
Y_pred = lg.predict(X_test)
print(classification_report(Y_test, Y_pred, digits=6))
# Out:
#              precision    recall  f1-score   support
#
#          0
#    0.811024  0.515785  0.630556      4593
#          1
#    0.818676  0.955871  0.881970     12758
#          2
#    0.982121  0.933565  0.957228      7767
#          3
#    0.990816  0.984787  0.987792     13475
#
# avg / total   0.910763  0.909103  0.904143     38593

# %%
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[ 2369,  2144,    33,    47],
#        [  428, 12195,    86,    49],
#        [   78,   411,  7251,    27],
#        [   46,   146,    13, 13270]])

# %%
# Достаём из векторайзера словарь
vocab = count_vectorizer.vocabulary_.items()
vocab = sorted(list(vocab), key=lambda x: x[1])
vocab_words, vocab_index = zip(*vocab)
vocab_words = np.array(vocab_words)

# %%
# vocab_words[-100:]
# Out:
# array(['ясли', 'ясна', 'ясная', 'яснее', 'ясней', 'ясно', 'ясного',
#        'ясное', 'ясной', 'ясноно', 'яснопонятно', 'ясности', 'ясность',
#        'ясностью', 'ясночто', 'ясноэто', 'ясную', 'ясны', 'ясные',
#        'ясный', 'ясным', 'ясными', 'ясных', 'яств', 'яства', 'яствами',
#        'яствах', 'яство', 'ят', 'ять', 'яффе', 'ях', 'яхта', 'яхте',
#        'яхтенного', 'яхту', 'яхты', 'яценюк', 'ячеек', 'ячейка',
#        'ячейками', 'ячейках', 'ячейке', 'ячейки', 'ячейку', 'ячменного',
#        'ячмень', 'ячменя', 'ячневая', 'яша', 'яшка', 'яшки', 'ящериц',
#        'ящерица', 'ящетаю', 'ящик', 'ящика', 'ящикам', 'ящиками',
#        'ящиках', 'ящике', 'ящики', 'ящиков', 'ящиком', 'ящику', 'ящитаю',
#        'ящичек', 'ящичке', 'яя', 'ёж', 'ёжик', 'ёжики', 'ёжиком', 'ёжику',
#        'ёй', 'ёлка', 'ёлки', 'ёлкой', 'ёлку', 'ёлочка', 'ёлочки',
#        'ёлочку', 'ёмкая', 'ёмкие', 'ёмкий', 'ёмким', 'ёмко', 'ёмкостей',
#        'ёмкости', 'ёмкость', 'ёмкостях', 'ёмоё', 'ёпрст', 'ёпта', 'ёрш',
#        'ёх', 'ёще', 'ёё', '为什么这么便宜呢', '是莫斯科中心吗'], dtype='<U41')

# %%
for label in range(4):
    _class_coef = lg.coef_[label]
    print('Class', label, 'слова увеличивающие вероятность класса:')
    print(list(vocab_words[ (-_class_coef).argsort()][:100]))
    print()
    print('Class', label,  'слова уменьшающие вероятность класса:')
    print(list(vocab_words[ (_class_coef).argsort()][:100]))
    print('-'*80)
# Out:
# Class 0 слова увеличивающие вероятность класса:
# ['подскажите', 'помогите', 'приготовить', 'рецепт', 'http', 'попробуй', 'noindex', 'тебе', 'тебя', 'кг', 'масло', 'мясо', 'воды', 'масла', 'href', 'варить', 'тесто', 'воду', 'вопрос', 'молоко', 'ем', 'посоветуйте', 'mail', 'бог', 'врачу', 'вкусно', 'чтоб', 'организма', 'яйца', '18', 'лук', 'суп', 'ответы', 'мартини', 'женщины', 'борщ', 'комп', 'смотри', 'мужчины', 'скачать', 'windows', 'span', 'смотря', 'майонез', 'спрятать', 'купи', 'нельзя', 'сколько', 'сахар', 'сок', 'предавали', 'лучше', 'ты', 'ли', 'gt', 'значит', 'бога', 'посмотри', 'ссср', 'сама', 'называется', 'водой', 'дней', 'соли', 'ru', 'мужчина', 'утром', 'какая', 'виски', 'вкус', 'готовить', 'теста', 'люди', 'ложки', 'кровь', 'вредно', 'муж', 'евреи', 'грибы', 'ей', 'маслом', 'молока', 'бери', 'больно', 'солнце', 'путин', 'помидоры', 'пить', 'или', 'ему', 'ответах', '_blank', 'нужна', 'салат', 'сахара', 'черный', 'видео', 'если', 'друг', 'народ']
#
# Class 0 слова уменьшающие вероятность класса:
# ['спасибо', 'книга', 'рекомендую', 'автор', 'читать', 'отличная', 'br', 'качество', 'del', 'интересно', 'компании', 'автора', 'картинки', 'общем', 'работает', 'понравилось', 'отличное', 'понятно', 'отличный', 'https', 'очень', 'приятно', 'видимо', 'согласен', 'заведение', 'подарок', 'целом', 'том', 'интересная', 'место', 'хабр', 'отлично', 'плюс', 'бизнес', 'действительно', 'кстати', 'книге', 'книжка', 'издание', 'хорошая', 'вполне', 'заказ', 'про', 'работать', 'персонал', 'надеюсь', 'эту', 'статья', 'статьи', 'иллюстрации', 'обслуживание', 'комментарий', 'всем', 'качестве', 'восторге', 'будто', 'статье', 'настолько', 'удобно', 'особенно', 'жаль', 'habrahabr', 'хабре', 'уровне', 'довольно', 'it', 'яндекс', 'статью', 'ребята', 'бар', 'сюда', 'супер', 'понял', 'совсем', 'достаточно', 'js', 'понравилась', 'информация', 'прекрасно', 'легко', 'кафе', 'цена', 'проект', 'ощущение', 'большой', 'таки', 'круто', 'история', 'сеть', 'молодцы', 'идея', 'просто', 'понравился', 'цены', 'места', 'книги', 'книг', 'абсолютно', 'времени', 'читал']
# --------------------------------------------------------------------------------
# Class 1 слова увеличивающие вероятность класса:
# ['статья', 'статьи', 'статью', 'com', 'del', 'хабр', 'статье', 'спасибо', 'https', 'согласен', 'хабре', 'яндекс', 'код', 'комментарий', 'пост', 'js', 'org', 'кода', 'проект', 'использовать', 'кстати', 'пример', 'понял', 'habrahabr', 'ага', 'ссылку', 'linux', 'данные', 'речь', 'выше', 'java', 'очевидно', 'используется', 'ru', 'программистов', 'разработчиков', 'написал', 'хабра', 'случае', 'api', 'имхо', 'правы', 'проще', 'it', 'пользователей', 'доступ', 'версии', 'приложение', 'например', 'решение', 'видел', 'верно', 'post', 'проекта', 'github', 'данных', 'работает', 'php', 'ide', 'проблема', 'google', 'ввиду', 'git', 'комментарии', 'вижу', 'работать', 'тогда', 'python', 'тоже', 'хм', 'сервер', 'баг', 'яндекса', 'поста', 'подумал', 'вариант', 'разработки', 'ос', 'простите', 'компании', 'приложения', 'да', 'поддерживаю', 'момент', 'карму', 'работал', 'веб', 'ссылки', 'статей', 'софт', 'коде', 'таки', 'проектов', 'насколько', 'про', 'задача', 'задачи', 'видео', 'зависит', 'писал']
#
# Class 1 слова уменьшающие вероятность класса:
# ['br', 'вкусно', 'книге', 'книга', 'рекомендую', 'заведение', 'книгу', 'мясо', 'качество', 'вкус', 'советую', 'персонал', 'книжка', 'вкусные', 'еда', 'кофе', 'издание', 'суп', 'кухня', 'понравилось', 'помогите', 'роллы', 'вкусная', 'вкусный', 'заведения', 'роман', 'приготовить', 'обслуживание', 'подскажите', 'кафе', 'салат', 'люблю', 'заказ', 'блюда', 'хорошее', 'ресторан', 'отзыв', 'интерьер', 'купила', 'книги', 'заведении', 'пицца', 'тебе', 'отзывы', 'фото', 'воды', 'noindex', 'пиво', 'поняла', 'иллюстрации', 'блюдо', 'тесто', 'готовить', 'ребенка', 'учебник', 'пиццу', 'читала', 'вкуснее', 'наклейки', 'бар', 'блюд', 'любовь', 'довольна', 'чай', 'пива', 'сюда', 'женщина', 'восторге', 'рецепт', 'еду', 'попробуй', 'официанты', 'еды', 'понравилась', 'сама', 'атмосфера', 'заказа', 'масла', 'любви', 'цена', 'вечер', 'бумага', 'бургеры', 'содержание', 'порции', 'коктейль', 'ребенку', 'детей', 'согласна', 'ем', 'настроение', 'ребенок', 'мяса', 'заказала', 'муж', 'пособие', 'девушка', 'готовят', 'официант', 'тебя']
# --------------------------------------------------------------------------------
# Class 2 слова увеличивающие вероятность класса:
# ['книга', 'br', 'книгу', 'книге', 'книги', 'книжка', 'издание', 'иллюстрации', 'читать', 'картинки', 'книг', 'автор', 'наклейки', 'роман', 'бумага', 'качество', 'рекомендую', 'читается', 'купила', 'задания', 'подарок', 'ребенку', 'понравилась', 'перевод', 'автора', 'читала', 'история', 'легко', 'страниц', 'обложка', 'сюжет', 'содержание', 'ребенок', 'учебник', 'прочтения', 'книжку', 'пособие', 'рисунки', 'альбом', 'серии', 'восторге', 'удовольствием', 'страницы', 'прочитала', 'яркие', 'интересная', 'советую', 'довольна', 'интересно', 'интересные', 'формат', 'карта', 'издания', 'оформление', 'ребенка', 'написано', 'прочитать', 'открытки', 'сказки', 'истории', 'отличная', 'книгой', 'произведение', 'советы', 'стихи', 'детям', 'одном', 'автору', 'понятно', 'информации', 'цена', 'хорошая', 'книжки', 'сборник', 'красивые', 'доступно', 'красочная', 'серия', 'яркая', 'бумаги', 'полезная', 'сын', 'эту', 'хороший', 'жизнь', 'ребёнок', 'шрифт', 'дочка', 'дыхании', 'каждой', 'текст', 'жизни', 'материал', 'этой', 'карты', 'эта', 'языком', 'детей', 'взгляд', 'путеводитель']
#
# Class 2 слова уменьшающие вероятность класса:
# ['вкусно', 'кофе', 'статья', 'там', 'место', 'вас', 'com', 'меню', 'заведение', 'вкусные', 'тут', 'туда', 'статьи', 'код', 'ru', 'сюда', 'обслуживание', 'статью', 'еда', 'подскажите', 'вам', 'персонал', 'статье', 'вкусный', 'кафе', 'был', 'мясо', 'обычно', 'цены', 'тоже', 'была', 'атмосфера', 'проблема', 'вкусная', 'кухня', 'да', 'вы', 'ресторан', 'делают', 'салат', 'музыка', 'видео', 'нормально', 'пожалуйста', 'вкус', 'пиво', 'зависит', 'будут', 'пицца', 'интерьер', 'вопрос', 'официанты', 'тогда', 'часто', 'роллы', 'del', 'хабр', 'бар', 'выше', 'ага', 'всегда', 'были', 'круто', 'пост', 'рублей', 'http', 'ну', 'https', 'бывает', 'сайт', 'кода', 'через', 'попробовать', 'помогите', 'типа', 'должно', 'попробуйте', 'сколько', 'ваш', 'нельзя', 'яндекс', 'суп', 'the', 'они', 'вкусное', 'уютно', 'вот', 'компания', 'хабре', 'значит', 'решение', 'молодцы', 'вообще', 'ты', 'windows', 'помню', 'тесто', 'выбор', 'если', 'недавно']
# --------------------------------------------------------------------------------
# Class 3 слова увеличивающие вероятность класса:
# ['заведение', 'вкусно', 'персонал', 'место', 'вкусные', 'обслуживание', 'кофе', 'еда', 'кафе', 'сюда', 'меню', 'кухня', 'интерьер', 'бар', 'ресторан', 'роллы', 'атмосфера', 'вкусная', 'заведения', 'официанты', 'пицца', 'цены', 'заказ', 'вкусный', 'заведении', 'ребята', 'бургеры', 'музыка', 'бургер', 'перекусить', 'официант', 'уютно', 'вкус', 'здесь', 'пиво', 'понравилось', 'бизнес', 'порции', 'блюд', 'готовят', 'блюда', 'принесли', 'отзыв', 'сегодня', 'народу', 'коктейли', 'мясо', 'городе', 'еды', 'еду', 'пончики', 'очереди', 'капучино', 'чай', 'выбор', 'салат', 'вечер', 'пиццу', 'вкусное', 'молодцы', 'пива', 'заказывали', 'поесть', 'официантка', 'акции', 'пироги', 'напитки', 'заказали', 'друзьями', 'рекомендую', 'столик', 'обслуживания', 'коктейль', 'зале', 'персонала', 'обстановка', 'заказа', 'рублей', 'посидеть', 'кальян', 'приятно', 'зал', 'местечко', 'места', 'пиццы', 'рядом', 'обед', 'всегда', 'бара', 'минут', 'ланч', 'девушка', 'баре', 'зашли', 'стол', 'радует', 'выпечка', 'мест', 'суп', 'заведений']
#
# Class 3 слова уменьшающие вероятность класса:
# ['книга', 'книги', 'книгу', 'br', 'читать', 'автор', 'лет', 'ru', 'статья', 'интересно', 'картинки', 'книге', 'com', 'автора', 'книжка', 'иллюстрации', 'жизнь', 'перевод', 'легко', 'будет', 'статью', 'текст', 'видео', 'издание', 'часть', 'книг', 'года', 'зависит', 'использовать', 'россии', 'язык', 'жизни', 'значит', 'статьи', 'например', 'бумага', 'страницы', 'windows', 'пример', 'многие', 'история', 'проще', 'подскажите', 'некоторые', 'понятно', 'хабр', 'информации', 'читается', 'автору', 'да', 'интернет', 'помощью', 'согласен', 'помогает', 'скорее', 'статье', 'надо', 'потом', 'случае', 'ему', 'версии', 'данные', 'нужна', 'del', 'www', 'может', 'вопрос', 'одном', 'ага', 'кто', 'страниц', 'хабре', 'задания', 'тему', 'помогите', 'сюжет', 'комментарий', 'яндекс', 'слова', 'http', 'жить', 'вариант', 'серии', 'альбом', 'фильм', 'сколько', 'решение', 'роман', 'сам', 'или', 'добавить', 'имеет', 'прочитать', 'читал', 'думаю', 'ней', 'год', 'вместе', 'ребенку', 'понял']
# --------------------------------------------------------------------------------

# %%
X_target = []
_Id = []
with open('source_task_test_without_labels.csv','r') as f:
    print(f.readline())
    for line in f:
        data = line.split(',')
        X_target.append(data[1])
        _Id.append(data[0])
# Out:
# _id,text

# %%
X_ = count_vectorizer.transform(X_target)

# %%
Y_target = lg.predict(X_)
with open('count_vec_lg.csv', 'w') as f:
    f.write('_id,label\n')
    for _id, y  in zip(_Id, Y_target):
        f.write('%s,%s\n' % (_id, y))

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.9, min_df=2)

# %%
X = tfidf_vectorizer.fit_transform(X_text)

# %%
X.shape
# Out:
# (154371, 160880)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
lg = LogisticRegression(
    penalty='l2',
    C=50, 
    n_jobs=-1, verbose=1, 
    solver='sag', multi_class='multinomial',
    max_iter=300
)
lg.fit(X_train, Y_train)
# Out:
# convergence after 113 epochs took 31 seconds
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:   31.1s finished
# LogisticRegression(C=50, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=300, multi_class='multinomial',
#           n_jobs=-1, penalty='l2', random_state=None, solver='sag',
#           tol=0.0001, verbose=1, warm_start=False)

# %%
Y_pred = lg.predict(X_test)
print(classification_report(Y_test, Y_pred, digits=6))
# Out:
#              precision    recall  f1-score   support
#
#          0
#    0.739179  0.729254  0.734183      4543
#          1
#    0.881358  0.912132  0.896481     12974
#          2
#    0.979073  0.941842  0.960097      7600
#          3
#    0.995513  0.987904  0.991694     13476
#
# avg / total   0.923725  0.922913  0.923150     38593

# %%
# Достаём из векторайзера словарь
vocab = tfidf_vectorizer.vocabulary_.items()
vocab = sorted(list(vocab), key=lambda x: x[1])
vocab_words, vocab_index = zip(*vocab)
vocab_words = np.array(vocab_words)

# %%
for label in range(4):
    _class_coef = lg.coef_[label]
    print('Class', label, 'слова увеличивающие вероятность класса:')
    print(list(vocab_words[ (-_class_coef).argsort()][:100]))
    print()
    print('Class', label,  'слова уменьшающие вероятность класса:')
    print(list(vocab_words[ (_class_coef).argsort()][:100]))
    print('-'*80)
# Out:
# Class 0 слова увеличивающие вероятность класса:
# ['посоветуйте', 'пищевые_добавки', 'вкусно', 'учителя', 'вес', 'noindex', 'предавали', 'модератором', 'семерки', 'посмотри', 'предприятия', 'ответах', 'видеокарта', 'спрятать', 'ищи', 'попробуй', 'финале', 'организма', 'предательство', 'подскажите', 'кг', 'пониже', 'уволен', 'приготовить', 'фентези', 'удешевленный', 'любви', 'нато', 'заморачиваюсь', 'submit', 'да', 'будущие', 'пчёлок', 'бэкапа', 'салон', 'предали', 'правления', 'интересуют', 'проги', 'бери', 'бога', 'своим', 'мартини', 'библии', 'подругу', 'компа', 'умом', 'ответы', 'учёный', 'инете', 'хочеш', 'разговоре', 'связанно', '18', 'человечности', 'мадам', 'интриги', 'подари', 'галустян', 'итальянский', 'href', 'масленицей', 'тач', 'explorer', 'нажми', 'энергетический', 'ломанули', 'библию', 'говоритьчто', 'рецептом', 'водой', 'переустановки', 'гр', 'дрожжи', 'переустановить', 'задуматся', 'шнурка', 'мужчины', 'купи', 'андрей', 'почитай', 'типаж', 'кхл', 'бандиты', 'помогите', 'пекарской', 'окружают', 'путина', 'смотри', 'sp1', 'лохотрон', 'рецептик', 'сходи', 'стошнило', 'suffer', 'поменяешь', 'фарш', 'рецепт', 'сомалийцев', 'pentium']
#
# Class 0 слова уменьшающие вероятность класса:
# ['спасибо', 'книга', 'автор', 'рекомендую', 'br', 'приятно', 'место', 'действительно', 'совершенно', 'общем', 'отличная', 'информация', 'целом', 'заказ', 'отличный', 'будто', 'атмосфера', 'настолько', 'эту', 'книге', 'почитать', 'отличное', 'компании', 'клиентов', 'качество', 'прекрасный', 'бар', 'свободный', 'прям', 'плюс', 'итоге', 'замечательная', 'сеть', 'писал', 'заведение', 'возможность', 'качестве', 'менеджер', 'странно', 'книгу', 'жду', 'бургер', 'цены', 'иллюстрации', 'автора', 'практически', 'прочтения', 'результат', 'отзыв', 'страниц', 'будем', 'респект', 'который', 'книжка', 'ситуации', 'симуляции', 'ребята', 'заказала', 'минус', 'том', 'нам', 'эта', 'бизнес', 'используется', 'говоря', 'симптомам', 'впечатление', 'https', 'детали', 'решил', 'оказалось', 'ждем', 'пришлось', 'автору', 'ценник', 'музыка', 'ощущение', 'качественно', 'восторге', 'клиент', 'местами', 'данном', 'понравилось', 'весьма', 'никуда', 'алгоритм', 'отличные', 'взял', 'котлета', 'пытался', 'персонал', 'вечером', 'продавец', 'уровне', 'жаль', 'особенно', 'но', 'знакомый', 'понравился', 'правильные']
# --------------------------------------------------------------------------------
# Class 1 слова увеличивающие вероятность класса:
# ['статья', 'статьи', 'статью', 'статье', 'спасибо', 'хабре', 'хабр', 'взрослая', 'получал', 'https', 'программист', 'кстати', 'согласен', 'проект', 'хабра', 'программиста', 'программистов', 'минусы', 'используется', 'js', 'ide', 'комментарий', 'api', 'com', 'продавали', 'яндекс', 'программисты', 'очевидно', 'алгоритм', 'симуляции', 'org', 'доступ', 'угу', 'проекты', 'да', 'симптомам', 'яндекса', 'пример', 'свободный', 'правы', 'кдпв', 'майнинг', 'карму', 'баг', 'linux', 'ресурс', 'потрясающая', 'разработчиков', 'посмотрел', 'сервер', 'версии', 'цб', 'электронная', 'комментариях', 'программировать', 'возможность', 'минске', 'никуда', 'сервисы', 'сайтов', 'ссылке', 'случаев', 'поддержку', 'btc', 'total', 'говорил', 'например', 'сутки', 'it', 'забрал', 'обновления', 'лету', 'коде', 'имел', 'случае', 'знал', 'разработчик', 'купальник', 'писал', 'ссылку', 'программистом', 'проглотил', 'hello', 'тз', 'применительно', 'базе', 'законах', 'разработчики', 'пользуются', 'постов', 'скрипт', 'github', 'теги', 'git', 'офис', 'публикации', 'подробнее', 'заказчик', 'простите', 'подумал']
#
# Class 1 слова уменьшающие вероятность класса:
# ['br', 'вкусно', 'книга', 'рекомендую', 'заведение', 'персонал', 'книги', 'кухня', 'фото', 'мясо', 'пищевые_добавки', 'еда', 'издание', 'вкусные', 'обслуживание', 'суп', 'роллы', 'нашла', 'блюда', 'кофе', 'заведения', 'вкус', 'noindex', 'вес', 'сюжет', 'море', 'содержание', 'захватывает', 'заказа', 'книгу', 'любви', 'учебник', 'протяжении', 'малыша', 'понравилась', 'ребенком', 'семерки', 'книге', 'мяса', 'еду', 'предавали', 'хочется', 'заведении', 'пониже', 'приготовить', 'др', 'максимова', 'съесть', 'пицца', 'блюдо', 'спрятать', 'ребёнок', 'финале', 'ребенка', 'смотрела', 'организма', 'сюда', 'будущие', 'лучший', 'руб', 'жизни', 'друзьями', 'пельмени', 'ресторан', 'блюд', 'хотела', 'подробно', 'роман', 'ребенок', 'гр', 'формат', 'воды', 'вкусная', 'пиццу', 'бери', 'уволен', 'наклейки', 'вкуснее', 'подаче', 'аутентичен', 'обложка', 'посмотри', 'отредактировали', 'капучино', 'submit', 'модератором', 'поняла', 'тесто', 'интерьер', 'вино', 'коктейль', 'вечер', 'кафе', 'бэкапа', 'вина', 'ела', 'согласна', 'книг', 'официант', 'города']
# --------------------------------------------------------------------------------
# Class 2 слова увеличивающие вероятность класса:
# ['br', 'книга', 'книгу', 'книге', 'книги', 'издание', 'книжка', 'книг', 'роман', 'рекомендую', 'автор', 'наклейки', 'обложка', 'читала', 'иллюстрации', 'путеводитель', 'автору', 'издания', 'ozon', 'купила', 'страниц', 'картинки', 'качественно', 'альбом', 'прочтения', 'читается', 'прочитала', 'учебник', 'понравилась', 'бумага', 'задания', 'открытки', 'содержание', 'автора', 'рисунки', 'книгой', 'пособие', 'ребенку', 'читать', 'сборник', 'курю', 'оформление', 'яркая', 'прочитать', 'перевод', 'детям', 'качество', 'полезного', 'издании', 'авторы', 'озон', 'плакат', 'легко', 'максимова', 'ребенок', 'рассказы', 'прочтению', 'ожидала', 'написана', 'сюжет', 'книгах', 'восторге', 'применить', 'обложке', 'книжку', 'прекрасный', 'озону', 'захватывает', 'упражнения', 'раскраска', 'бросила', 'карточки', 'романа', 'бумаги', 'ребенка', 'сыну', 'доволен', 'произведение', 'наклеек', 'занимаемся', 'интересные', 'переплет', 'детектив', 'довольна', 'психология', 'карты', 'колода', 'прочла', 'страницы', 'трогательно', 'красочная', 'пожалеете', 'картинок', 'эту', 'информации', 'качественная', 'родителям', 'яркие', 'подробно', 'малышам']
#
# Class 2 слова уменьшающие вероятность класса:
# ['да', 'зачем', 'получал', 'там', 'взрослая', 'подробнее', 'чаем', 'едой', 'минусы', 'вкусно', 'меню', 'давай', 'геометрии', 'продавали', 'помогу', 'проблема', 'потрясающая', 'двое', 'хочеш', 'обычно', 'федора', 'статья', 'место', 'встречать', 'сутки', 'вас', 'проглотил', 'были', 'вообще', 'кафе', 'черную', 'статью', 'музыку', 'свежая', 'заведение', 'вот', 'фентези', 'был', 'можете', 'статьи', 'какую', 'симонова', 'похоже', 'кофе', 'пойду', 'подсказать', 'пишите', 'вам', 'блог', 'программиста', 'хабре', 'посоветуйте', 'зависит', 'com', 'пост', 'наводку', 'кухня', 'искушенных', 'пожалуйста', 'фильмы', 'сюда', 'решения', 'потребовалось', 'туда', 'геморроя', 'пора', 'вкусный', 'пицца', 'роллы', 'менеджера', 'ситуация', 'статье', 'вы', 'ресторан', 'предметно', 'связалось', 'помнил', 'ценная', 'конкретно', 'майнинг', 'видно', 'транзистор', 'примерно', 'прослезился', 'англоязычное', 'подскажите', 'попробовать', 'жалобы', 'электронная', 'вкусные', 'выложить', 'музыка', 'освоение', 'них', 'подарки', 'жалоб', 'предложенных', 'говорит', 'вкус', 'становятся']
# --------------------------------------------------------------------------------
# Class 3 слова увеличивающие вероятность класса:
# ['заведение', 'место', 'персонал', 'обслуживание', 'кофе', 'бар', 'кафе', 'интерьер', 'кухня', 'еда', 'вкусные', 'вкусно', 'сюда', 'заведения', 'вкусная', 'цены', 'заведении', 'ресторан', 'меню', 'официанты', 'бургеры', 'атмосфера', 'музыка', 'роллы', 'заказ', 'капучино', 'порции', 'бургер', 'пончики', 'перекусить', 'уютно', 'ребята', 'персонала', 'принесли', 'рекомендую', 'вкусный', 'отзыв', 'стол', 'повара', 'мест', 'коктейли', 'зале', 'пироги', 'поесть', 'заказывали', 'латте', 'вечер', 'обстановка', 'заказали', 'молодцы', 'посидеть', 'сеть', 'народу', 'официантка', 'ценник', 'пива', 'заведений', 'очереди', 'кальян', 'чек', 'зайти', 'блюд', 'приятно', 'пицца', 'обслуживания', 'сегодня', 'блюда', 'суп', 'зал', 'напитки', 'бариста', 'городе', 'дорого', 'приду', 'ресторана', 'друзьями', 'местечко', 'ассортимент', 'кофейня', 'ланч', 'мясо', 'попробовала', 'гостей', 'начинки', 'акции', 'бара', 'компанией', 'готовят', 'официантов', 'кухни', 'фри', 'официант', 'обед', 'вид', 'целом', 'посещения', 'ланчи', 'выбор', 'выпечка', 'вкус']
#
# Class 3 слова уменьшающие вероятность класса:
# ['книга', 'книги', 'книгу', 'читать', 'br', 'жизнь', 'интернет', 'автор', 'книге', 'лет', 'легко', 'хлебушек', 'написано', 'или', 'статья', 'смотря', 'часть', 'ozon', 'автора', 'интересно', 'молотый', 'затем', 'орет', 'пример', 'получится', 'жизни', 'надеюсь', 'подбирают', 'казани', 'рассказчик', 'вторые', 'птицу', 'картинки', 'магазинах', 'сша', 'видео', 'зависит', 'магазине', 'перевод', 'магазины', 'доставлена', 'будет', 'тонкий', 'теме', 'первую', 'субпродукты', 'имеют', 'размешивать', 'учиться', 'например', 'америке', 'нужна', 'жить', 'список', 'станет', 'иллюстрации', 'вспомнили', 'рынке', 'электронная', 'информации', 'зрения', 'пр', 'месяц', 'озон', 'года', 'посмотрите', 'годами', 'истории', 'собственного', 'повернуть', 'школе', 'выглядит', 'история', 'значит', '11', 'пункт', 'неё', 'использовать', 'издание', 'ага', 'страниц', 'душком', 'консервантов', 'товаров', 'сроки', 'случае', 'роман', 'краснодар', 'книжка', 'автору', 'полгода', 'рецепты', 'опыт', 'сюжет', 'потом', 'windows', 'ru', 'итальянский', 'россии', 'альбом']
# --------------------------------------------------------------------------------

# %%
X_= tfidf_vectorizer.transform(X_target)

# %%
Y_target = lg.predict(X_)
with open('tfidf_vec_lg.csv', 'w') as f:
    f.write('_id,label\n')
    for _id, y  in zip(_Id, Y_target):
        f.write('%s,%s\n' % (_id, y))

# %%
import pymorphy2

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
parsed_word = morph.parse('борща')[0]

# %%
parsed_word
# Out:
# Parse(word='борща', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='борщ', score=1.0, methods_stack=((DictionaryAnalyzer(), 'борща', 135, 1),))

# %%
parsed_word.normal_form
# Out:
# 'борщ'

# %%
parsed_word.tag
# Out:
# OpencorporaTag('NOUN,inan,masc sing,gent')

# %%
parsed_word.tag.POS
# Out:
# 'NOUN'

# %%
morph.parse('стали')
# Out:
# [Parse(word='стали', tag=OpencorporaTag('VERB,perf,intr plur,past,indc'), normal_form='стать', score=0.975274, methods_stack=((DictionaryAnalyzer(), 'стали', 923, 4),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='сталь', score=0.010989, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 1),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='сталь', score=0.005494, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 6),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='сталь', score=0.002747, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 2),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='сталь', score=0.002747, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 5),)),
#  Parse(word='стали', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='сталь', score=0.002747, methods_stack=((DictionaryAnalyzer(), 'стали', 13, 9),))]
